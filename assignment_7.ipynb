# %% [markdown]
# # Assignment 7
#
# Sabine Segaloff
#
# 11/18/25
#
# ### Do any five.

# %% [markdown]
# ## 1.

# %% [markdown]
# ### 1.1 What is the expected value of a single die roll?

# %% [markdown]
# Recall that the expected value of a random variable $X$ is
# $$
# \mathbb{E}[X] = \begin{cases} \int_{x \in \text{supp}(X)} x \times f_X(x)dx, & \text{$X$ continuous}\\
# \sum_{x \in \text{supp}(X)} x \times m_X(x), & \text{$X$ discrete}.
# \end{cases}
# $$
#
# A single die roll is

# %% [markdown]
# The data is discrete, so we calculate:
# $$
# \mathbb{E}[X] = \sum_{x \in \text{supp}(X)} x \times m_X(x)
# $$
#
# where $m_X(x)$ is the probability mass function.
#
# For a die, which has 6 equally likely outcomes, we have a uniform distribution where the PMF is just a list of $P(1)=1/6, P(2)=1/6, \dots, P(6)=1/6$.
#
# The support of $X$ is $\{1,2,3,4,5,6\}$ because these are the only values the die can land on.
#
# So, for a single die roll,
# $$
# \mathbb{E}[X] = \sum_{x \in \{1,2,3,4,5,6\}} x \times \frac{1}{6}
# $$
# Plugging in our PMF,
# $$
# \mathbb{E}[X] = 1\frac{1}{6} + 2\frac{1}{6} + 3\frac{1}{6} + 4\frac{1}{6} + 5\frac{1}{6} + 6\frac{1}{6}
# $$
# Adding these up, we find
# $$
# \mathbb{E}[X] = \frac{21}{6} = 3.5
# $$

# %% [markdown]
# ### 1.2 What is the expected value of rolling two dice and adding the results together?

# %% [markdown]
# We know the expecation is linear. So, $\mathbb{E}[X_1 + X_2] = \mathbb{E}[X_1] + \mathbb{E}[X_2]$
#
# So, we plug in our findings from above,
#
# $$\mathbb{E}[X_1 + X_2] = \mathbb{E}[X_1] + \mathbb{E}[X_2] = 3.5 + 3.5 = 7$$

# %% [markdown]
# ### 1.3 What is the expected winnings of any gamble in European roulette?

# %% [markdown]
# In European roulette, we have 37 slots for the ball to land in (1-36 and a single 0). There is an equal probability of landing in each slot.
#
# So, if we pay one dollar to bet on K slots, and we have probability of $\frac{K}{37}$, if we win we get $\frac{36}{K}$ dollars and if we lose, which has a probability of $\frac{(37-K)}{37}$, we get $0$ dollars.
#
# So, the expected winnings for any bet is
#
# $$\mathbb{E}[\text{Winnings}]=(\text{win probability})(\text{win payoff})+(\text{lose probability})(\text{lose payoff})-(\text{initial bet})$$
#
# We plug in our probabilities and payoffs to find
# $$\mathbb{E}[\text{Winnings}]=\left(\frac{K}{37}\right)\left(\frac{36}{K}\right)+\left(\frac{(37-K)}{37}\right)(0) - 1$$
#
# Simplify
# $$\mathbb{E}[\text{Winnings}]=\frac{36}{37}-1=-0.027$$
#
# So, any one-dollar roulette bet has an expected payoff of $-0.027$ dollars.

# %% [markdown]
# ### 1.4 Imagine you roll a die, and you record the value you get. But, if you roll a six, you roll again, and add that value. What is the expected value?

# %% [markdown]
# This is a conditional expectation.
#
# - Case A: You don't roll a 6. You roll 1-5. There case has a $5/6$ probability. $(1+2+3+4+5)/5 = 15/5=3$ The average of these outputs is 3.
#     - So the expectation here is $\frac{5}{6}\times 3=\frac{15}{6}$
#
# - Case B: You roll a 6. There case has a $1/6$ probability. $(1+2+3+4+5+6)/6 = 21/6=3.5$. You have 6 plus the value of a new roll (which has an average value of 3.5).
#     - So the expectation here is $\frac{1}{6}\times(9.5)=\frac{1}{6}\times \frac{19}{2} = \frac{19}{12}$

# %% [markdown]
# So, we have
# $$
# \mathbb{E}[X] = \frac{15}{6}+\frac{19}{12}
# $$

# %% [markdown]
# $$
# \mathbb{E}[X] = \frac{49}{12} \approx 4.0833
# $$

# %% [markdown]
# ### 1.5 Imagine that the process described in the last question continues until you fail to roll a six. What is the expected value of the process? (This can be tricky, you can simulate it to get an answer if you prefer. Hint: The answer is 4.2.)

# %% [markdown]
# This is recursive (if we roll 6, and then roll 6, we keep rolling until we don't roll 6).
#
# Let $E$ be the expected value.
# - If we roll a 1-5, (probability $5/6$), the game ends. The average value of this is $3$.
# - If we roll a 6, (probability $1/6$), we have 6 plus we are again in same situation, $E$.
#
# So,
# $$
# E = \frac{5}{6}(3) + \frac{1}{6}(6+E)
# $$
#
# We can simplify to
# $$
# E = \frac{15}{6} + \frac{6}{6}+\frac{E}{6} = \frac{21}{6} + \frac{E}{6}
# $$
#
# We can subtract \frac{E}{6} from both sides to get
# $$
# \frac{6E}{6} - \frac{E}{6}= \frac{21}{6}
# $$
#
# Which becomes
# $$
# \frac{5}{6}E = \frac{21}{6}
# $$
#
# And multiply both sides by $6/5$ to get
# $$
# E = \frac{21}{6} \times \frac{6}{5} = \frac{21}{5}
# $$
#
# Finally we divide to find
# $$
# E = 4.2
# $$

# %% [markdown]
# ## 2.
# - Compute the expected value for a uniform random variable.
# - Show that $\mathbb{E}[a+bX] = a + b\mathbb{E}[X]$
# - Show, by example, that $v(\mathbb{E}[X]) \neq \mathbb{E}[v(X)]$, if $v(x) \neq a+bx$. For example, try $v(y) = y^2$ or $v(y)=\sqrt{y}$ with a Bernoulli or uniform or normally distributed random variable. This can be an important thing to remember: The expectation of a transformed random variable is not the transformation of the expected value.

# %% [markdown]
# ### 2.1 Compute the expected value for a uniform random variable

# %% [markdown]
# We know that the PDF for a uniform random variable is
#
# $$
# f(x) =\frac{1}{b-a}, \quad a\le x \le b
# $$
#
# The support is $[a,b]$.
#
# Recall that the expected value of a random variable $X$ is
# $$
# \mathbb{E}[X] = \begin{cases} \int_{x \in \text{supp}(X)} x \times f_X(x)dx, & \text{$X$ continuous}\\
# \sum_{x \in \text{supp}(X)} x \times m_X(x), & \text{$X$ discrete}.
# \end{cases}
# $$
#
# If we consider a continous variable, we will use an integral. And since our probability is 0 everywhere except between $a$ and $b$, we can bound our integral.
#
# So, we have
# $$
# \mathbb{E}[X] = \int_a^b x \times \left(\frac{1}{b-a}\right)dx
# $$
#
# We pull out the constant $\frac{1}{b-a}$
# $$
# \mathbb{E}[X] = \left(\frac{1}{b-a}\right) \int_a^b x dx
# $$
#
# We integrate
# $$
# \mathbb{E}[X] = \left(\frac{1}{b-a}\right) \left[\frac{x^2}{2}\right]_a^b
# $$
#
# And evaluate at the bounds
# $$
# \mathbb{E}[X] = \left(\frac{1}{b-a}\right) \left(\frac{b^2}{2}-\frac{a^2}{2}\right)=\left(\frac{1}{b-a}\right) \left(\frac{b^2-a^2}{2}\right) = \frac{b^2-a^2}{2(b-a)}
# $$
#
# Recall difference of squares
# $$
# \mathbb{E}[X] = \frac{(b-a)(b+a)}{2(b-a)}
# $$

# %% [markdown]
# Cancel out $(b-a)$ terms
# $$
# \mathbb{E}[X] = \frac{b+a}{2}
# $$

# %% [markdown]
# ### 2.2 Show that $\mathbb{E}[a+bX] = a + b\mathbb{E}[X]$

# %% [markdown]
# We need to prove the linearity of the expectation. We want to show that if we scale a variable $(bX)$ and shift it $(a)$, the average scales and shifts exactly the same way.
#
# $$\mathbb{E}[a+bX] =\int_{-\infty}^\infty (a+bx)f(x)dx$$
#
# Break the integral into two parts (integrals are linear operators so we can do this)
# $$\mathbb{E}[a+bX] =\int_{-\infty}^\infty af(x)dx+ \int_{-\infty}^\infty bxf(x)dx$$
#
# Pull out the constants $a$ and $b$
# $$\mathbb{E}[a+bX] =a\int_{-\infty}^\infty f(x)dx+ b\int_{-\infty}^\infty xf(x)dx$$
#
# Notice that
# $\int_{-\infty}^\infty f(x)dx$ is the total area under the curve and thus equals $1$ (because its probability) and, by definition, that $\int_{-\infty}^\infty xf(x)dx$ is $\mathbb{E}[X]$.
#
# So, we have
# $$\mathbb{E}[a+bX] =a(1)+b\mathbb{E}[X]=a+b\mathbb{E}[X]$$

# %% [markdown]
# ### 2.3 Show, by example, that $v(\mathbb{E}[X]) \neq \mathbb{E}[v(X)]$, if $v(x) \neq a+bx$. For example, try $v(y) = y^2$ or $v(y)=\sqrt{y}$ with a Bernoulli or uniform or normally distributed random variable. This can be an important thing to remember: The expectation of a transformed random variable is not the transformation of the expected value.

# %% [markdown]
# In other words, an example is: the square of the average is not the average of the squares.
#
# I'll use the unifrom distribution to prove this.
#
# Let $X \sim \text{Uniform}(0,1)$. Here, $a=0$ and $b=1$. From part 2.1, we know that $\mathbb{E}[X]=\frac{0+1}{2}=0.5$.
#
# So, for the left side, $v(\mathbb{E}[X])$ (the square of the expectation), plug in the expectation:
# $$v(0.5)=(0.5)^2=.25$$
#
# And for the right side, $\mathbb{E}[v(X)]$ (the expected value of the square), we calculate:
# $$\mathbb{E}[X^2]=\int_0^1 x^2 \times f(x)dx$$
#
# Since $f(x)=\frac{1}{1-0}=1$, we know
# $$\mathbb{E}[X^2]=\int_0^1 x^2 dx$$
#
# Now we integrate and evaluate at the bounds
# $$\mathbb{E}[X^2]=\left[\frac{x^3}{3}\right]_0^1=\frac{1^3}{3}-\frac{0^3}{3}=\frac{1}{3} \approx 0.333$$
#
# We can easily see that
# $$0.25 \neq 0.333$$
#
# So, $v(\mathbb{E}[X]) \neq \mathbb{E}[v(X)]$.

# %% [markdown]
# ## 3.
# - Compute the variance for a uniform random variable.
# - Show that
# $$
# \mathbb{V}[X] = \mathbb{E}[X^2] - \mathbb{E}[X]^2
# $$
# $$
# \mathbb{V}[a+bX] = b^2 \mathbb{V}[X]
# $$
# - Show that if $X$ is a normally distributed random variable, then $a + bX$ is distributed normally with mean $a+ b \mathbb{E}[X]$ and variance $b^2 \sigma_X^2$
#
# These properties get used all the time!

# %% [markdown]
# ### 3.1 Compute the variance for a uniform random variable.

# %% [markdown]
# I'm using the property we will prove in the next part to do this part.
#
# Recall $\mathbb[X^2]$ from question 2.
# $$\mathbb{E}[X^2]=\int_a^b x^2 \times f(x)dx=\int_a^b x^2 \times \frac{1}{b-a}dx$$
#
# Pull out the constant and integrate $x^2$
# $$\mathbb{E}[X^2]=\frac{1}{b-a}\int_a^b x^2 dx=\frac{1}{b-a}\left(\frac{b^3-a^3}{3}\right)$$
#
# Factor difference of cubes
# $$\mathbb{E}[X^2]=\frac{1}{b-a}\times \frac{(b-a)(b^2+ab+a^2)}{3}$$
#
# Cancel out $(b-a)$ terms
# $$\mathbb{E}[X^2]=\frac{b^2+ab+a^2}{3}$$
#
# Now let's recall the $(\mathbb{E}[X])^2$ from question 2, $(\frac{a+b}{2})^2$
#
# So,
#
# $$\mathbb{V}[X] = \frac{b^2+ab+a^2}{3} - \left(\frac{a+b}{2}\right)^2$$
# $$\mathbb{V}[X] = \frac{b^2+ab+a^2}{3} - \frac{a^2+2ab+b^2}{4}$$
#
# Use 12 as common denominator
# $$\mathbb{V}[X] = \frac{4(b^2+ab+a^2)}{12} - \frac{3(a^2+2ab+b^2)}{12}$$
#
# Simplify
# $$\mathbb{V}[X] = \frac{4b^2+4ab+4a^2-3a^2-6ab-3b^2}{12}$$
#
# Simplify further
# $$\mathbb{V}[X] = \frac{b^2-2ab+a^2}{12}$$
#
# Factor the perfect square
# $$\mathbb{V}[X] = \frac{(b-a)^2}{12}$$

# %% [markdown]
# ### 3.2a Show that
# $$
# \mathbb{V}[X] = \mathbb{E}[X^2] - \mathbb{E}[X]^2
# $$

# %% [markdown]
# The variance is defined as the average squared distance from the mean
#
# $$
# \mathbb{V}[X] = \int_{x} (x - \mathbb{E}[X])^2 f(x) dx
# $$
#
# We can expand this out to
# $$
# \mathbb{V}[X] = \int_{x} (x^2 - 2x\mathbb{E}[X]+ (\mathbb{E}[X])^2)f(x) dx
# $$
#
# Which becomes
# $$
# \mathbb{V}[X] = \int_{x} (x)^2 f(x) dx -\int_{x} (\mathbb{E}[X])^2 f(x) dx
# $$
#
#
# Which then is
# $$
# \mathbb{V}[X] = \int_{x} (x^2)f(x) dx -2\mathbb{E}[X]\int_{x} xf(x) dx +(\mathbb{E}[X])^2\int_{x}f(x) dx
# $$
#
# We further simplify to
# $$
# \mathbb{V}[X] = \mathbb{E}[X^2] -2\mathbb{E}[X]^2+\mathbb{E}[X]^2
# $$
#
# Then we add to get
# $$
# \mathbb{V}[X] = \mathbb{E}[X^2] -\mathbb{E}[X]^2
# $$

# %% [markdown]
# ### 3.2b Show that
# $$
# \mathbb{V}[a+bX] = b^2 \mathbb{V}[X]
# $$

# %% [markdown]
# Here we prove that variance isn't linear.
#
# $$
# \mathbb{V}[a+bX] = \int(x - \mathbb{E}[a+bX])^2 f(x) dx
# $$
#
# $$
# \mathbb{V}[a+bX] =\int (a+bX - a - b \mathbb{E}[X])^2 f(x)dx
# $$
#
# $$
# \mathbb{V}[a+bX] =\int (bX - b \mathbb{E}[X])^2 f(x)dx
# $$
#
# $$
# \mathbb{V}[a+bX] =\int b^2(X -\mathbb{E}[X])^2 f(x)dx
# $$
#
# $$
# \mathbb{V}[a+bX] =b^2\int (X -\mathbb{E}[X])^2 f(x)dx
# $$
#
# $$
# \mathbb{V}[a+bX] =b^2\mathbb{V}[X]
# $$

# %% [markdown]
# $$
# \mathbb{V}[a+bX] =b^2\mathbb{V}[X]
# $$

# %% [markdown]
# ### 3.3 Show that if $X$ is a normally distributed random variable, then $a + bX$ is distributed normally with mean $a+ b \mathbb{E}[X]$ and variance $b^2 \sigma_X^2$

# %% [markdown]
# A fundamental property of the Normal distribution is that any linear transformation of a Normal variable is also Normal.
#
# So, we just need to find the new mean and variance for Y=a+bX.
#
# In Question 2, we proved that Expectation is linear.
#
# $$\mathbb{E}[Y]=\mathbb{E}[a+bX]=a+b\mathbb{E}[X]$$
#
# Since $X \sim N(\mu, \sigma^2)$, then $\mathbb{E}[X]=\mu$. So the new mean is $a+b\mu$.
#
# In Question 3, we proved that Variance scales by the square of the constant.
#
# $$\mathbb{V}[Y]=\mathbb{V}[a+bX]=b^2\mathbb{V}[X]$$
#
# (Recall that the shift $a$ doesn't affect the spread.)
#
# Since $\mathbb{V}[X]=\sigma^2$, the new variance is $b^2\sigma^2$.
#
# So, $a+bX \sim N(a+b\mu, b^2\sigma^2)$.

# %% [markdown]
# ## 4.
#
# - The **covariance** of $X$ and $Y$ is
# $$
# \text{cov}(X,Y) = \int_{y} \int_{x} (x-\mathbb{E}[X])(y-\mathbb{E}[Y])f_{XY}(x,y) dxdy = \mathbb{E}_{XY}[ (x-\mu_X)(y-\mu_Y)]
# $$
# - Show that if $f_{XY}(x,y)=f_X(x)f_Y(y)$, then $\text{cov}(X,Y)=0$
# - Provide an example (computation/simulation is fine) where $\text{cov}(X,Y)\approx 0$ but $f_{XY}(x,y)\neq 0$
# - The covariance doesn't characterize joint random variables except in a few special cases: The covariance only captures the **linear** association between the two variables, not nonlinear associations.

# %% [markdown]
# ## 5.
#
# Suppose $X$ has an expectation $\mathbb{E}[X]<\infty$ and variance $\mathbb{V}[X]<\infty$; this isn't always true, but is *usually* true
# - Consider making a new variable, $\varepsilon = X - \mathbb{E}[X]$
# - What's the expectation of $\varepsilon$?
# - What's the variance of $\varepsilon$?
# - So we can write any random variable in the form $X = \mathbb{E}[X] + \varepsilon, $ where $\mathbb{E}[\varepsilon]=0$ and $\mathbb{V}[\varepsilon] = \sigma_X^2$
# - If that's true, show that we can also write any random variable in the form $X = \mathbb{E}[X] + \sigma_X \varepsilon$, where $\mathbb{E}[\varepsilon]=0$ and $\mathbb{V}[\varepsilon]=1$
# - Now replace $\mathbb{E}[X]$ with $x\beta$, and the stage is set for regression models

# %% [markdown]
# ## 6.
# - Use the Taylor series expansions
# $$
# F(x+h) = F(x) + hf(x) + \frac{h^2}{2}f'(x) + O(h^3)
# $$
# and
# $$
# F(x-h) = F(x) - h f(x) + \frac{h^2}{2} f'(x)+ O(h^3)
# $$
# to show that
# $$
# \mathbb{E}[\hat{f}_{X,h}(x)] = \frac{F(x+h)-F(x-h)}{2h} = f(x) + O(h^2),
# $$
# so the **bias** of the KDE is $O(h^2)$, unlike the ECDF, for which $\mathbb{E}[\hat{F}(x)] = F(x)$.

# %% [markdown]
# ## 7.
# - Suppose $X$ and $Y$ are distributed bivariate normal. Show that if $\rho=0$, then $X$ and $Y$ are independent.
# - For the multivariate normal, show that if $\Sigma$ is a diagonal matrix, then $X_1, X_2, ..., X_n$ are independent.
# - For the multivariate normal, show that if $\Sigma$ is a diagonal matrix and all the $\sigma_i^2$ and all the $\mu_i$ are equal, then $X_1, X_2, ..., X_n$ are independently distributed random variables with distribution $N(\mu, \sigma^2)$

# %% [markdown]
# ## 8.
# - Open the METABRIC data. Make a histogram of 'Ratio Therapy'.
# - Let treatment, $T$ be distributed binomial with parameter $p$. Then the contribution to the likelihood for each patient $i$, with $y_i = 0$ for no radiation therapy and $y_i=1$ for radiation therapy, is
# $$
# p^{y_i}(1-p)^{1-y_i}
# $$
# - Write out the likelihood.
# - Maximize the likelihood with respect to $p$. What is the MLE, $\hat{p}$?
# - Bootstrap the sampling density/distribution of $\hat{p}$.

# %%
# get data and libraries

import pandas as pd
import numpy as np
import seaborn as sns
import scipy as sp
import matplotlib.pyplot as plt

df = pd.read_csv('/Users/sabinesegaloff/Code/UVA_Fall_25/Understanding_Uncertainty_5030/data/metabric.csv')

# %% [markdown]
# ### 8.1 Make a histogram of 'Ratio Therapy'

# %%
# make the histogram

y = df['Radio Therapy']
sns.histplot(y,stat='proportion')
plt.show()

# %% [markdown]
# ### 8.2 - Write out the likelihood

# %% [markdown]
# Since our patients are independent, we multiply the probabilities together.
#
# We know that the likelihood function is the joint density of the error terms, by independence. (More simply, its how likely is it that we would see a specific combination of data points, given a specific parameter $p$.)
#
# The formula for likelihood is
# $$L(p) = \prod_{i=1}^n f_{X_i}(x_i; p)$$
#
# $$L(p) = \prod_{i=1}^n p^{y_i}(1-p)^{1-y_i}$$

# %% [markdown]
# ### 8.3 Maximize the likelihood with respect to $p$. What is the MLE, $\hat{p}$?

# %% [markdown]
# Maximizing is an optimization problem, so we will take the derivative, set it to 0, and solve for $\hat{p}$. This will be easier if we maximize the log likelihood instead. Since log is a strictly increasing function, the peak for the log likelihood will be at the same place as the peak for the regular likelihood.
#
# To maximize, we first take logs. Which allows us to split our multiplication up into addition.
# $$
# \ell(p) = \sum_{i=1}^n y_i \log(p) + \left(1-\sum_{i=1}y_i\right) \log(1-p)
# $$
#
# Now let's take the derivative
# $$
# \ell'(p) = \frac{1}{p}\sum_{i=1}^n y_i - \frac{1}{1-p}\left(1-\sum_{i=1}^ny_i\right)
# $$
#
# And set it to zero and solve for $\hat{p}$
# $$
# \frac{1}{\hat{p}} \sum_{i=1}^n y_i - \frac{1}{1-\hat{p}}\left(1-\sum_{i=1}^ny_i\right)  = 0
# $$
#
# This simplifies to
# $$
# \frac{\sum_{i=1}^n y_i}{\hat{p}} - \frac{\left(1-\sum_{i=1}^ny_i\right)}{1-\hat{p}}  = 0
# $$
#
# Moving the right fraction to the right hand side, we have
# $$
# \frac{\sum_{i=1}^n y_i}{\hat{p}} = \frac{\left(1-\sum_{i=1}^ny_i\right)}{1-\hat{p}}
# $$
#
# Multiplying both sides by $\hat{p}(1-\hat{p})$ gives
# $$
# (1-\hat{p})\sum_{i=1}^n y_i = \hat{p}\left(1-\sum_{i=1}^ny_i\right)
# $$
#
# This simplifies to
# $$
# \sum_{i=1}^n y_i-\hat{p}\sum_{i=1}^n y_i = \hat{p}-\hat{p}\sum_{i=1}^ny_i
# $$
#
# Add $\hat{p}\sum_{i=1}^ny_i$ to both sides to get our MLE
# $$
# \hat{p}=\sum_{i=1}^n y_i
# $$

# %% [markdown]
# ### 8.4 - Bootstrap the sampling density/distribution of $\hat{p}$

# %%
# bootstrap the sampling distribution
# convert data from string to numeric
y = pd.to_numeric( y.replace({'NO':'0','YES':'1'}) , errors='coerce')

# return the original MLE
print(f'Original MLE: ', y.mean())

# set the number of simulations
n_sim = 5000
n_size = len(df) # size of original dataset

# create an empty list for the findings
boot_dist_p = []

# loop through the number of simulations
for i in range(n_sim):
    # sample with replacement from the original dataset
    sample = np.random.choice(y, size=n_size, replace=True)

    # get and store the MLE of each sample
    boot_dist_p.append(sample.mean())
    
# convert to numpy array
boot_dist_p = np.array(boot_dist_p)

# visualize results
plt.figure(figsize=(10, 6))
sns.histplot(boot_dist_p, stat='density', kde=True)
plt.axvline(y.mean(), color='red', linestyle='--', label=f'Original MLE: {y.mean():.3f}')
plt.title('Bootstrapped Sampling Distribution of p_hat')
plt.xlabel('Estimated Probability (p)')
plt.legend()
plt.show()
# Out:
# Original MLE:  0.659717051377513

# %% [markdown]
# ## 9.
# - Open the Ames house price data. Make a KDE of 'price'. Select an appropriate distribution for modeling it, and explain why you selected it. (Hint: You might want to take a common transformation of price.)
# - Derive the density for this distribution.
# - Write out the likelihood.- Maximize the likelihood. What is the MLE?
# - Plot the density/distribution for your fitted model and compare it to the KDE/ECDF. Criticize the fit.
# - Bootstrap the sampling density/distribution of your parameters.

# %%
ames = pd.read_csv('/Users/sabinesegaloff/Code/UVA_Fall_25/Understanding_Uncertainty_5030/data/ames_prices.csv')

# %% [markdown]
# ### 9.1 Make a KDE of 'price'. Select an appropriate distribution for modeling it and explain why you selected it.

# %% [markdown]
# Price data is always positive. Its also right skewed because of a couple of super expensive houses. Due to skew I am looking at the log of price.

# %%
# make a kde of 'price'
prices = ames['price']
log_prices = np.log(ames['price'])
sns.histplot(log_prices,stat='proportion')
plt.show()

# %% [markdown]
# This looks relatively bell shaped and symmetric with a peak at 12, so I'll say that price is **log-normally distributed**.

# %% [markdown]
# ### 9.2 Derive the density for this distribution

# %% [markdown]
# I want to derive $f_Y(y)$ for the price $Y$.
#
# I know that since I transformed price $Y$ using $X = \log(Y)$, that $X$ is normally distributed
# $$X \sim N(\mu, \sigma^2)$$
# where $\mu$ is the mean and $\sigma$ is the standard deviation.
#
# I already know that the density for the normal distribution is
# $$
# f(x; \mu, \sigma) =  \frac{1}{\sqrt{2\pi }\sigma} \exp \left\lbrace - \frac{(x-\mu)^2}{2\sigma^2} \right\rbrace
# $$
# where $\exp(x) = e^x$
#
# And I already know that the density for the log normal distribution is
# $$
# f(x;\mu,\sigma) = \dfrac{1}{\sqrt{2\pi} x \sigma} \exp \left( - \dfrac{(\ln(x)-\mu)^2}{2\sigma^2} \right)= \dfrac{1}{x \sigma} \phi \left( \dfrac{\ln(x)-\mu}{\sigma} \right)
# $$
#
# where $\exp(x) = e^x$

# %% [markdown]
# So, for this log-normal distribution, I have
# $$
# f_Y(y) = \frac{1}{\sqrt{2\pi} y \sigma} e^{\left( - \dfrac{(\ln(y)-\mu)^2}{2\sigma^2} \right)}
# $$

# %% [markdown]
# Which simplifies to
# $$
# f_Y(y) = \frac{1}{\sqrt{2\pi} y \sigma} e^{ -\dfrac{1}{2} \left(\dfrac{(\ln(y)-\mu)}{\sigma} \right)^2}
# $$

# %% [markdown]
# ### 9.3 Write out the likelihood

# %% [markdown]
# $$L(\mu,\sigma)=\prod_{i=1}^n f_Y(y_i; \mu, \sigma)$$
#
# Plug in our density equation
#
# $$L(\mu,\sigma)=\prod_{i=1}^n  \frac{1}{\sqrt{2\pi} y \sigma} e^{ -\dfrac{1}{2} \left(\dfrac{(\ln(y)-\mu)}{\sigma} \right)^2}$$

# %% [markdown]
# ### 9.4 Maximize the likelihood. What is the MLE?

# %% [markdown]
# Take log likelihood
# $$\ell (\mu,\sigma) = \sum_{i=1}^n \ln(f_Y(y_i))$$
#
# For $\hat{\mu}$, its the mean of the log-transformed data:
# $$\hat{\mu} = \frac{1}{n}\sum_{i=1}^n \ln(y_i)$$
#
# For $\hat{\sigma}$, its the standard deviation of the log-transformed data
#
# $$\hat{\sigma}=\sqrt{\frac{1}{n}\sum_{i=1}^n (\ln(y_i)-\mu^2)}$$

# %% [markdown]
# ### 9.5 Plot the density/distribution for your fitted model and compare it to the KDE/ECDF. Criticize the fit.

# %%
from scipy import stats

# calculate stats on log data
mu_hat = log_prices.mean()
sigma_hat = log_prices.std()

print(f'mu_hat: {mu_hat:.4f}')
print(f'sigma_hat: {sigma_hat:.4f}')

# plot pdf vs kde and cdf vs ecdf
fig, axes = plt.subplots(1,2,figsize=(14,6))

# plot empirical data (KDE)
sns.kdeplot(x=prices,ax=axes[0],label='kde', color='blue')

# plot the fitted log normal model
x_range = np.linspace(prices.min(),prices.max(),2000)
pdf_vals = stats.lognorm.pdf(x_range,s=sigma_hat,scale=np.exp(mu_hat))
sns.lineplot(x=x_range,y=pdf_vals,ax=axes[0],label='pdf',linestyle='--',color='red')
plt.title('Ames House Prices: KDE vs Fitted Log-Normal Distribution')

# plot empirical data (ECDF)
sns.ecdfplot(x=prices,ax=axes[1],label='ecdf', color='blue')

# plot the fitted log normal model
x_range = np.linspace(prices.min(),prices.max(),2000)
cdf_vals = stats.lognorm.cdf(x_range,s=sigma_hat,scale=np.exp(mu_hat))
sns.lineplot(x=x_range,y=cdf_vals,ax=axes[1],label='cdf',linestyle='--',color='red')
plt.title('Ames House Prices: ECDF vs Fitted Log-Normal Distribution')

plt.show()
# Out:
# mu_hat: 12.0210
# sigma_hat: 0.4076

# %% [markdown]
# The model does not capture the peak of the KDE. It does capture the right tail. There are a few pumbs in the kde which may indicate clusters of homes missed by the pdf.

# %% [markdown]
# ### 9.6 Bootstrap the sampling density/distribution of your parameters.

# %%
# set the number of simulations
n_sim = 2000
# create an empty list for the findings
boot_mus = []
boot_sigmas = []

# loop through the number of simulations
for sim in range (n_sim):
    # sample with replacement from the original dataset
    sample = np.random.choice(prices, size=len(prices), replace=True)

    # get and store the MLE of each sample
    log_sample = np.log(sample)
    boot_mus.append(log_sample.mean())
    boot_sigmas.append(log_sample.std())
    
# visualize uncertainty
fig, ax = plt.subplots(1,2,figsize=(14,6))
sns.histplot(boot_mus, ax=ax[0], kde=True, color='purple')
ax[0].set_title(r'Sampling Density of $\hat{\mu}$')
ax[0].set_xlabel('Estimated Mu')
sns.ecdfplot(boot_mus, ax=ax[1], color='purple')
ax[0].set_title(r'Sampling Distribution of $\hat{\mu}$')
ax[0].set_xlabel('Estimated Mu')
plt.show()


fig, ax = plt.subplots(1,2,figsize=(14,6))
sns.histplot(boot_sigmas, ax=ax[0], kde=True, color='purple')
ax[0].set_title(r'Sampling Density of $\hat{\mu}$')
ax[0].set_xlabel('Estimated Sigma')
sns.ecdfplot(boot_sigmas, ax=ax[1], color='green')
ax[1].set_title(r'Sampling Distribution of $\hat{\sigma}$')
ax[1].set_xlabel('Estimated Sigma')
plt.show()

# %% [markdown]
# ## 10.
# - Open the METABRIC data. Make a KDE of 'Overall Survival (Months)'.
# - Let survival time, $T$ be distributed exponentially with parameter $\lambda$. Then its distribution is
# $$
# F(t) = 1 - e^{-\lambda t} = p[T\le t].
# $$
# - Derive the density for this distribution.
# - Write out the likelihood.
# - Maximize the likelihood with respect to $\lambda$. What is the MLE, $\hat{\lambda}$?
# - Plot the density/distribution for your fitted model and compare it to the KDE/ECDF. Criticize the fit.
# - Bootstrap the sampling density/distribution of $\hat{\lambda}$.

# %% [markdown]
# ## 11.
# - Open the Ames house price data. Make a histogram of 'TotRms.AbvGrd', or total rooms above ground.
# - We're going to model this using the Poisson Distribution. The probability that $y_i = k$ is given by
# $$
# pr[y_i = k ] = \frac{ \lambda^k e^{-\lambda} }{k!}
# $$
# - Write out the likelihood.
# - Maximize the likelihood. What is the MLE? (Hint: The sample mean. As usual.)
# - Plot the density/distribution for your fitted model and compare it to the KDE/ECDF. Criticize the fit.
# - Bootstrap the sampling density/distribution of your parameter.

# %% [markdown]
# ## 12.
# - Open the METABRIC data. Make a histogram of 'Mutation Count' with around 50 bins. Let $Y$ be the mutation count the random variable, and $y_i$ the mutation count for patient $i$.
# - We're going to model this using the Poisson Distribution. The probability that $y_i = k$ is given by
# $$
# pr[y_i = k ] = \frac{ \lambda^k e^{-\lambda} }{k!}
# $$
# - Write out the likelihood.
# - Maximize the likelihood. What is the MLE? (Hint: The sample mean. As usual.)
# - Plot the density/distribution for your fitted model and compare it to the KDE/ECDF. Criticize the fit.
# - Bootstrap the sampling density/distribution of your parameter.
